# %% [markdown]
# # visualisation avec seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme()

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="day",style='time') ;
#' style': pour le style d'affichage des scatter
#' hue 'variable qui produira des pionts avec une colonne with boollean et qui a plusieurs valeur (non boolean)

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",style='sex') 
## hu et style pour la memee colonne
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",size='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",size='size') 
## hue et style pour la memee colonne
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
flights=sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flights, x='year', y="passengers",estimator=max)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x='year', y="passengers",hue='month')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
rips=sns.load_dataset('taxis',parse_dates=["pickup","dropoff"])
rips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
rips['hour']=rips['pickup'].dt.hour

# %%
rips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.lineplot(data=rips, x='hour', y="total",hue='payment',style='color',ci=None)
#ci pour l'intervalle de confiance
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.relplot(data=rips, x='hour', y="total",kind='line',hue='payment',col='pickup_borough',row='dropoff_borough',ci=None);
# relplot() pour les sous figures

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=flights, x='year', y="passengers",hue='month')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.relplot(data=tips, x='total_bill', y="tip",kind='scatter',hue='smoker',col='day',row='sex',height=3,aspect=1);

# %%
sns.histplot(data=tips,x="tip",hue='smoker',multiple="dodge")
# dodge / stack / fill
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x="tip",hue='smoker')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
penguins=sns.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=penguins,x="body_mass_g",binwidth=500)
### pour la largeur de bins (binwidth)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="body_mass_g",bins=20)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="body_mass_g",bins=20,hue='species',multiple='stack',element='step')
#la forme d'aafichage du element du histogramme  'bar' est par défaut (poly// step)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="body_mass_g",bins=20,hue='species',multiple='stack',palette='flare')
### plette les distributions du coleur
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.rugplot(data=tips,x='tip',height=0.1)
# rugplot() pour la creation descodebars
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
sns.rugplot(data=tips,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(kind='ecdf',data=penguins,x='body_mass_g',height=3,aspect=2)
# 'kde hist ecdf' les types de kind quise trouve dans displot()

# %%
sns.displot(x="body_mass_g",data=penguins,col='species',hue='sex')

# %%
sns.displot(data=tips,kind='hist',x='total_bill',y='tip',rug=True)

# %%
sns.countplot(data=penguins,x='species',hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.countplot(data=tips,x='time',hue='smoker')
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
titanic=pd.read_csv('titanic.csv')

# %%
sns.countplot(data=titanic,x='pclass',hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic,y='pclass',hue='sex')
# Out:
# <AxesSubplot:xlabel='count', ylabel='pclass'>

# %%
sns.stripplot(data=rips,x='pickup_borough',y='distance')
plt.title('taxi trip distance by burough')
# stripplot() pour que les données ne seront plus chi dkhl f chi chauvauchement
# Out:
# Text(0.5, 1.0, 'taxi trip distance by burough')

# %%
trip_sample=rips.nlargest(600,"total")

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=trip_sample,x='pickup_borough',y='distance')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=rips,x='pickup_borough',y='distance')
# lavaleur d'ereur
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=rips,x='pickup_borough',y='total',estimator=sum)
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='total'>

# %%
rips.groupby('pickup_borough')['total'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pickup_borough'>

# %%
sns.barplot(data=rips,x='pickup_borough',y='distance',hue='color')
# Out:
# <AxesSubplot:xlabel='pickup_borough', ylabel='distance'>

# %%
#rips

# %%
sns.barplot(data=rips,y='pickup_borough',x='distance',hue='color',dodge=False)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='pickup_borough'>

# %%
sns.barplot(data=titanic,y='pclass',x='survived')
## orient pour l'orientation
# Out:
# <AxesSubplot:xlabel='survived', ylabel='pclass'>

# %%
sns.catplot(data=titanic,x='sex',y='survived',kind='bar')

# %%
sns.catplot(data=titanic,x='sex',y='survived',kind='bar',col='pclass')

# %%
sns.catplot(data=titanic,x='pclass',y='survived',kind='bar',hue='sex')

# %%
sns.catplot(data=rips,x='pickup_borough',y='distance',kind='strip',col='color',aspect=0.8)

# %%
titanic2=sns.load_dataset('titanic')
sns.catplot(data=titanic2,x='who',y='survived',kind='bar',col='pclass',ci=None)

# %%
sns.catplot(data=titanic2,x='who',y='survived',kind='box',col='pclass',ci=None)
