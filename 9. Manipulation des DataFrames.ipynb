# %% [markdown]
# # Exercices d'application : Manipulation des DataFrames
# Importer les datasets suivants :
# - kc_house_data.csv
# - titanic.csv
# - netflix_titles.csv
# - coin_Bitcoin
# - world-happiness-report-2021.csv
# Exécuter les lignes de codes et expliquer les résultats obtenus:

# %%
import pandas as pd
houses = pd.read_csv("kc_house_data.csv.xls")
titanic = pd.read_csv("titanic.csv")
netflix = pd.read_csv("netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("coin_Bitcoin.csv")
countries = pd.read_csv("world-happiness-report-2021.csv")

# %% [markdown]
# ### Exercice 1: btc dataframe
#     a. Expliquer le rôle de drop
#     b. Expliquer la synthaxe

# %%
btc.drop(labels="Symbol", axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %% [markdown]
#     c. Comparer les résultats obtenus on utilisant ces 2 lignes de codes.
#     d. Qu'est ce qu'on remarque ?

# %%
btc.drop(labels=["SNo", "Name", "Symbol"], axis='columns')
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc.drop(columns=["SNo", "Name", "Symbol"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %% [markdown]
#     e. A quoi sert inplace ?

# %%
btc.drop(columns=["SNo", "Name", "Symbol"], inplace=True)

# %%
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %% [markdown]
#     f. Qu'est ce qu'on peut déduire de la syntaxe suivante?

# %%
btc[["Date", "High", "Low"]]
# Out:
#                      Date          High           Low
# 0     2013-04-29 23:59:59    147.488007    134.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003
# 2     2013-05-01 23:59:59    139.889999    107.720001
# 3     2013-05-02 23:59:59    125.599998     92.281898
# 4     2013-05-03 23:59:59    108.127998     79.099998
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169
#
# [2991 rows x 3 columns]

# %% [markdown]
#     g. Expliquer le résultat obtenu

# %%
btc.sort_index(ascending=False, inplace=True)
btc.drop(2990)
# Out:
#                      Date          High           Low          Open  \
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2985  2021-07-01 23:59:59  35035.982712  32883.781226  35035.982712
# ...                   ...           ...           ...           ...
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap
# 2989  33746.002456  2.672155e+10  6.326962e+11
# 2988  35287.779766  2.492431e+10  6.615748e+11
# ...

# %% [markdown]
#     h. Que fait set_index et reset_index?

# %%
btc.set_index("Date", inplace=True)
btc
# Out:
#                              High           Low          Open         Close  \
# Date
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# ...                           ...           ...           ...           ...
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
#
#                            Volume     Marketcap
# ...

# %%
btc.reset_index( inplace=True)
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 1     2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2     2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 3     2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 4     2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 2986  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 2987  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2988  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 2989  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2990  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap
# 0     34235.193451  2.650126e+10  6.418992e+11
# 1     33746.002456  2.672155e+10  6.326962e+11
# ...

# %% [markdown]
#     i.Expliquer les résultats obtenus

# %%
btc["change"] = btc["Close"] - btc["Open"]
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 1     2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2     2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 3     2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 4     2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 2986  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 2987  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2988  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 2989  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2990  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap       change
# 0     34235.193451  2.650126e+10  6.418992e+11   511.683796
# ...

# %%
btc.sort_values("change", ascending=False)
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 1     2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2     2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 3     2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 4     2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 2986  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 2987  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2988  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 2989  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2990  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap       change
# 0     34235.193451  2.650126e+10  6.418992e+11   511.683796
# ...

# %%
btc["delta"] = btc["High"] - btc["Low"]
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 1     2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2     2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 3     2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 4     2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 2986  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 2987  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2988  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 2989  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2990  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap       change        delta
# 0     34235.193451  2.650126e+10  6.418992e+11   511.683796  1438.620194
# ...

# %%
btc.sort_values("delta", ascending=False)
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 1     2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2     2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 3     2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 4     2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...                   ...           ...           ...           ...
# 2986  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 2987  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2988  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 2989  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2990  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap       change        delta
# 0     34235.193451  2.650126e+10  6.418992e+11   511.683796  1438.620194
# ...

# %% [markdown]
#     j. Détailler les étapes de cette instruction

# %%
btc.sort_values("delta", ascending=False).head(10)["delta"].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exercice 2 : countries dataframe
#     a. Expliquer les résultats obtenus

# %%
countries.set_index('Country name',inplace =True)

# %%
countries.drop(labels="Denmark", axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
#     b. Que fait drop suivant cette instruction

# %%
countries.drop(["Denmark", "Iceland", "Finland"])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %% [markdown]
#     c. Expliquer les 2 syntaxes suivantes

# %%
countries.drop(countries.index[0])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.drop(countries.index[10:])
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Finland              Western Europe         7.842
# Denmark              Western Europe         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway               Western Europe         7.392
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %% [markdown]
#     d. Expliquer la syntaxe suivante

# %%
countries.loc[countries['Regional indicator'].str.contains('South')]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Singapore        Southeast Asia         6.377                           0.043
# Thailand         Southeast Asia         5.985                           0.047
# Philippines      Southeast Asia         5.880                           0.052
# Vietnam          Southeast Asia         5.411                           0.039
# Malaysia         Southeast Asia         5.384                           0.049
# Indonesia        Southeast Asia         5.345                           0.056
# Nepal                South Asia         5.269                           0.070
# Maldives             South Asia         5.198                           0.072
# Laos             Southeast Asia         5.030                           0.045
# Bangladesh           South Asia         5.025                           0.046
# Pakistan             South Asia         4.934                           0.068
# ...

# %% [markdown]
#     e. Que fait isnull() et notnull()?

# %%
countries.isnull()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland                    False         False
# Denmark                    False         False
# Switzerland                False         False
# Iceland                    False         False
# Netherlands                False         False
# ...                          ...           ...
# Lesotho                    False         False
# Botswana                   False         False
# Rwanda                     False         False
# Zimbabwe                   False         False
# Afghanistan                False         False
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                False         False         False
# Denmark                                False         False         False
# Switzerland                            False         False         False
# ...

# %%
countries.notnull()
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland                     True          True
# Denmark                     True          True
# Switzerland                 True          True
# Iceland                     True          True
# Netherlands                 True          True
# ...                          ...           ...
# Lesotho                     True          True
# Botswana                    True          True
# Rwanda                      True          True
# Zimbabwe                    True          True
# Afghanistan                 True          True
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                 True          True          True
# Denmark                                 True          True          True
# Switzerland                             True          True          True
# ...

# %% [markdown]
#     f. Que fait hasnans?

# %%
countries['Regional indicator'].hasnans
# Out:
# False

# %%
countries.index[:].hasnans
# Out:
# False

# %% [markdown]
# ## Exercice 3 : titanic dataframe

# %% [markdown]
#     a. Expliquer le contenu de ces 2 cellules

# %%
titanic["species"] = "human"
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.drop(columns=["species"], inplace=True)

# %% [markdown]
#     b. Détailler les résultats obtenus

# %%
titanic["sibsp"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64

# %%
titanic["parch"]
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic["sibsp"] + titanic["parch"]
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic["num_relatives"] = titanic["sibsp"] + titanic["parch"]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
#     c. Expliquer le résultat de ces cellules

# %%
titanic.sort_values("num_relatives", ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic[titanic["survived"] == 1].sort_values("num_relatives", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
solo_passengers = titanic["num_relatives"] == 0
titanic[solo_passengers].sex.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %% [markdown]
#     d. Détailler les sous-instructions de la cellule suivante

# %%
titanic.sex.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %% [markdown]
#     e. Expliquer le résultat obtenu

# %%
cols = list(titanic.columns.values)
titanic[cols[2:5]+ [cols[1]] + [cols[-1]] + [cols[0]]+ cols[5:-1]]
# Out:
#                                                  name     sex     age  \
# 0                       Allen, Miss. Elisabeth Walton  female      29
# 1                      Allison, Master. Hudson Trevor    male  0.9167
# 2                        Allison, Miss. Helen Loraine  female       2
# 3                Allison, Mr. Hudson Joshua Creighton    male      30
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25
# ...                                               ...     ...     ...
# 1304                             Zabour, Miss. Hileni  female    14.5
# 1305                            Zabour, Miss. Thamine  female       ?
# 1306                        Zakarian, Mr. Mapriededer    male    26.5
# 1307                              Zakarian, Mr. Ortin    male      27
# 1308                               Zimmerman, Mr. Leo    male      29
#
#       survived  num_relatives  pclass  sibsp  parch  ticket      fare  \
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ### Exercice 4 :  houses dataframe
#     a. Expliquer le résultat obtenu

# %%
houses.insert(0, "county", "King County")
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %% [markdown]
#     b. Que fait cette instruction ?

# %%
houses["sale_price"] = houses["price"]

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %% [markdown]
#     c. Comment on peut expliquer le résultat de ces cellules

# %%
houses.insert(3, "num_bedrooms", houses["bedrooms"])

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King County  7129300520  20141013T000000             3  221900.0
# 1      King County  6414100192  20141209T000000             3  538000.0
# 2      King County  5631500400  20150225T000000             2  180000.0
# 3      King County  2487200875  20141209T000000             4  604000.0
# 4      King County  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000             3  360000.0
# 21609  King County  6600060120  20150223T000000             4  400000.0
# 21610  King County  1523300141  20140623T000000             2  402101.0
# 21611  King County   291310100  20150116T000000             3  400000.0
# 21612  King County  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %% [markdown]
#     d. Expliquer les résultats obtenus

# %%
houses["price_sqft"] = houses["price"] / houses["sqft_living"]

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King County  7129300520  20141013T000000             3  221900.0
# 1      King County  6414100192  20141209T000000             3  538000.0
# 2      King County  5631500400  20150225T000000             2  180000.0
# 3      King County  2487200875  20141209T000000             4  604000.0
# 4      King County  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000             3  360000.0
# 21609  King County  6600060120  20150223T000000             4  400000.0
# 21610  King County  1523300141  20140623T000000             2  402101.0
# 21611  King County   291310100  20150116T000000             3  400000.0
# 21612  King County  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %% [markdown]
#     e. Expliquer le résultat

# %%
houses.sort_values("price_sqft", ascending=False)
# Out:
#             county          id             date  num_bedrooms      price  \
# 19336  King County  6021500970  20150407T000000             2   874950.0
# 4013   King County   724069059  20140509T000000             3  2400000.0
# 10446  King County  1118000320  20150508T000000             4  3400000.0
# 8623   King County  6303400395  20150130T000000             1   325000.0
# 9314   King County  4389200610  20141201T000000             2   903000.0
# ...            ...         ...              ...           ...        ...
# 1385   King County  3342700465  20150123T000000             3   250000.0
# 17197  King County  5111400086  20140512T000000             3   110000.0
# 13825  King County  5637200450  20141017T000000             5   257000.0
# 3785   King County   723049156  20140523T000000             3   149000.0
# 18262  King County  2891000610  20141211T000000             4   148900.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values("price_sqft", ascending=False).head(50)["zipcode"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
#     f. Que permet unique() et nunique()?

# %%
houses.bedrooms.unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
houses.bedrooms.nunique()
# Out:
# 13

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic['sex'].replace("female","f",inplace=True)

# %%
titanic['sex'].replace(["female","male"],["f","m"])
# Out:
# 0       f
# 1       m
# 2       f
# 3       m
# 4       f
#        ..
# 1304    f
# 1305    f
# 1306    m
# 1307    m
# 1308    m
# Name: sex, Length: 1309, dtype: object

# %%
titanic['age'].replace("?",None).value_counts(dropna=False)
### katkon par défaut f value_count(dropna=True)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc["Brazil",["Ladder score","Healthy life expectancy"]]
# Out:
# Ladder score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[["Costa Rica","Panama","Honduras"],["Ladder score","Healthy life expectancy"]]
# Out:
#               Ladder score  Healthy life expectancy
# Country name
# Costa Rica           7.069                   71.400
# Panama               6.180                   69.652
# Honduras             5.919                   67.300

# %%
countries.loc["Finland",["upperwhisker","lowerwhisker"]]="MEON"
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score upperwhisker lowerwhisker  \
# Country name
# Finland                                0.032         MEON         MEON
# Denmark                                0.035        7.687        7.552
# Switzerland                            0.036        7.643          7.5
# Iceland                                0.059         7.67        7.438
# ...

# %%
countries.loc[["Finland","Denmark","Iceland","Sweden","Norway"],["Regional indicator","iscold"]]="DOGS!!!"
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland                  DOGS!!!         7.842
# Denmark                  DOGS!!!         7.620
# Switzerland       Western Europe         7.571
# Iceland                  DOGS!!!         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score upperwhisker lowerwhisker  \
# Country name
# Finland                                0.032         MEON         MEON
# Denmark                                0.035        7.687        7.552
# Switzerland                            0.036        7.643          7.5
# Iceland                                0.059         7.67        7.438
# ...

# %%
countries.loc[["Finland","Denmark","Iceland","Sweden","Norway"],["Regional indicator","iscold"]]=["Nordic countries","yes!"]
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland         Nordic countries         7.842
# Denmark         Nordic countries         7.620
# Switzerland       Western Europe         7.571
# Iceland         Nordic countries         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score upperwhisker lowerwhisker  \
# Country name
# Finland                                0.032         MEON         MEON
# Denmark                                0.035        7.687        7.552
# Switzerland                            0.036        7.643          7.5
# Iceland                                0.059         7.67        7.438
# ...

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King County  7129300520  20141013T000000             3  221900.0
# 1      King County  6414100192  20141209T000000             3  538000.0
# 2      King County  5631500400  20150225T000000             2  180000.0
# 3      King County  2487200875  20141209T000000             4  604000.0
# 4      King County  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000             3  360000.0
# 21609  King County  6600060120  20150223T000000             4  400000.0
# 21610  King County  1523300141  20140623T000000             2  402101.0
# 21611  King County   291310100  20150116T000000             3  400000.0
# 21612  King County  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.iloc[0,3]=7
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King County  7129300520  20141013T000000             7  221900.0
# 1      King County  6414100192  20141209T000000             3  538000.0
# 2      King County  5631500400  20150225T000000             2  180000.0
# 3      King County  2487200875  20141209T000000             4  604000.0
# 4      King County  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000             3  360000.0
# 21609  King County  6600060120  20150223T000000             4  400000.0
# 21610  King County  1523300141  20140623T000000             2  402101.0
# 21611  King County   291310100  20150116T000000             3  400000.0
# 21612  King County  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
high_quality=houses["grade"]>12
great_views=houses["view"]==4
print(great_views)
print("__________________________________________")
print(high_quality)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: view, Length: 21613, dtype: bool
# __________________________________________
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: grade, Length: 21613, dtype: bool

# %%
pd.options.display.max_rows=1999
houses.loc[high_quality & great_views,['luxury_level']]='ultra'
houses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\1015836985.py in <module>
#       1 pd.options.display.max_rows=1999
# ----> 2 houses.loc[high_quality & great_views,['luxury_level']]='ultra'
#       3 houses
#
# NameError: name 'high_quality' is not defined

# %%
houses[houses['luxury_level']].count_values
houses
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'luxury_level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
